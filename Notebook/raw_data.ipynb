# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../resources/raw_traffic_data.csv', sep='[,;:]' ,index_col=False)
data.head(10)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18992\792201054.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('../../resources/raw_traffic_data.csv', sep='[,;:]' ,index_col=False)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18992\792201054.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv('../../resources/raw_traffic_data.csv', sep='[,;:]' ,index_col=False)
#    track_id             type   traveled_d   avg_speed        lat        lon  \
# 0         1              Car        48.85    9.770344  37.977391  23.737688
# 1         2       Motorcycle        98.09   19.839417  37.977642  23.737400
# 2         3       Motorcycle        63.80   18.228752  37.977997  23.737264
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 922 entries, 0 to 921
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     922 non-null    int64
#  1    type        922 non-null    object
#  2    traveled_d  922 non-null    float64
#  3    avg_speed   922 non-null    float64
#  4    lat         922 non-null    float64
#  5    lon         922 non-null    float64
#  6    speed       922 non-null    float64
#  7    lon_acc     922 non-null    float64
#  8    lat_acc     922 non-null    float64
#  9    time        922 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 72.2+ KB

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=data, x=" type")
plt.title(f'Distribution of vehicle type', size=20, fontweight='bold')
plt.show()

# %%
sns.displot(data=data, x=" traveled_d",
                    kde=True, height=7, aspect=2)
plt.title(f'Distribution of traveled distance', size=20, fontweight='bold')
plt.show()

# %% [markdown]
# #Processed data

# %%
trajectory_df = pd.read_csv('../trajectories_info.csv',index_col=False)
trajectory_df.head(10)
# Out:
#                  unique_id        lat        lon   speed  lon_acc  lat_acc  \
# 0  20181024_d1_0830_0900_0  37.977391  23.737688  4.9178   0.0518  -0.0299
# 1  20181024_d1_0830_0900_0  37.977391  23.737688  4.9207  -0.0124  -0.0354
# 2  20181024_d1_0830_0900_0  37.977391  23.737688  4.9160  -0.0519  -0.0413
# 3  20181024_d1_0830_0900_0  37.977390  23.737688  4.9057  -0.0914  -0.0478
# 4  20181024_d1_0830_0900_0  37.977390  23.737689  4.8871  -0.1679  -0.0550
# 5  20181024_d1_0830_0900_0  37.977389  23.737689  4.8547  -0.2815  -0.0628
# 6  20181024_d1_0830_0900_0  37.977389  23.737689  4.8033  -0.4320  -0.0713
# 7  20181024_d1_0830_0900_0  37.977388  23.737690  4.7318  -0.5617  -0.0804
# 8  20181024_d1_0830_0900_0  37.977388  23.737690  4.6442  -0.6543  -0.0905
# 9  20181024_d1_0830_0900_0  37.977388  23.737690  4.5437  -0.7413  -0.1017
#
#    time
# 0  0.00
# 1  0.04
# 2  0.08
# 3  0.12
# 4  0.16
# 5  0.20
# 6  0.24
# 7  0.28
# 8  0.32
# 9  0.36

# %%
vehic_df = pd.read_csv('../vehicle_info.csv',index_col=False)
vehic_df.head(10)
# Out:
#                  unique_id  track_id        veh_type  traveled_distance  \
# 0  20181024_d1_0830_0900_0         1             Car              48.85
# 1  20181024_d1_0830_0900_1         2      Motorcycle              98.09
# 2  20181024_d1_0830_0900_2         3      Motorcycle              63.80
# 3  20181024_d1_0830_0900_3         4      Motorcycle             145.72
# 4  20181024_d1_0830_0900_4         5      Motorcycle             138.01
# 5  20181024_d1_0830_0900_5         6  Medium Vehicle             159.97
# 6  20181024_d1_0830_0900_6         7      Motorcycle             153.91
# 7  20181024_d1_0830_0900_7         8             Car             158.21
# 8  20181024_d1_0830_0900_8         9             Car             161.01
# 9  20181024_d1_0830_0900_9        10             Car             159.53
#
#    avg_speed
# 0   9.770344
# 1  19.839417
# 2  18.228752
# 3  26.229014
# 4  24.841425
# 5  17.451502
# 6  22.895895
# 7  21.739084
# 8  21.154471
# 9  18.891989
